# %%
# 📦 Step 1: Install Dependencies
# !pip install keras tensorflow

# %%
# pip install streamlit

# %%
# 🧹 Step 2: Import Libraries
import streamlit as st

import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# %%
# # 📄 Step 3: Sample Corpus (replace this with your own dataset!)
# corpus = [
#     "I am going to the store",
#     "I am going to the park",
#     "He is reading a book",
#     "She is playing in the garden",
#     "They are going for a walk"
# ]


# Load and clean your dataset
with open("stories.txt.utf-8", "r", encoding="utf-8") as file:
    text = file.read().lower()

# Optional: Split into lines or sentences
corpus = text.split("\n")  # one line per training example

# Remove empty lines
corpus = [line.strip() for line in corpus if line.strip()]

# %%
# 🧼 Step 4: Tokenization and Sequence Creation
tokenizer = Tokenizer()
tokenizer.fit_on_texts(corpus)
total_words = len(tokenizer.word_index) + 1

# Create input sequences
input_sequences = []
for line in corpus:
    token_list = tokenizer.texts_to_sequences([line])[0]
    for i in range(1, len(token_list)):
        n_gram_sequence = token_list[:i+1]
        input_sequences.append(n_gram_sequence)

# Pad sequences
max_sequence_len = max([len(x) for x in input_sequences])
input_sequences = np.array(pad_sequences(input_sequences, maxlen=max_sequence_len, padding='pre'))

# Split input and label
X = input_sequences[:, :-1]
y = input_sequences[:, -1]
y = to_categorical(y, num_classes=total_words)

# %%
# 🧠 Step 5: Define the LSTM Model
model = Sequential()
model.add(Embedding(total_words, 50, input_length=max_sequence_len - 1))
model.add(LSTM(100))
model.add(Dense(total_words, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_2 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
# 🏋️ Step 6: Train the Model
model.fit(X, y, epochs=200, verbose=1)
# Out:
# Epoch 1/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - accuracy: 0.0750 - loss: 7.1041
# Epoch 2/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.0979 - loss: 6.3461
# Epoch 3/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.1014 - loss: 6.2096
# Epoch 4/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.1167 - loss: 5.9443
# Epoch 5/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.1274 - loss: 5.7847
# Epoch 6/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.1433 - loss: 5.6206
# Epoch 7/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.1447 - loss: 5.4690
# Epoch 8/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.1485 - loss: 5.3463
# Epoch 9/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.1516 - loss: 5.2147
# Epoch 10/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.1564 - loss: 5.0734
# Epoch 11/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.1557 - loss: 4.9705
# Epoch 12/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.1718 - loss: 4.8031
# Epoch 13/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.1740 - loss: 4.6924
# Epoch 14/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.1848 - loss: 4.5141
# Epoch 15/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.1990 - loss: 4.3751
# Epoch 16/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.1961 - loss: 4.2556
# Epoch 17/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.2139 - loss: 4.1238
# Epoch 18/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.2268 - loss: 3.9757
# Epoch 19/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.2513 - loss: 3.8307
# Epoch 20/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.2651 - loss: 3.7035
# Epoch 21/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.2909 - loss: 3.5553
# Epoch 22/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.3206 - loss: 3.4136
# Epoch 23/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.3498 - loss: 3.2533
# Epoch 24/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.3608 - loss: 3.1521
# Epoch 25/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.3854 - loss: 3.0339
# Epoch 26/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.4194 - loss: 2.8928
# Epoch 27/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.4414 - loss: 2.7525
# Epoch 28/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.4574 - loss: 2.6650
# Epoch 29/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.4776 - loss: 2.5443
# Epoch 30/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.5017 - loss: 2.4293
# Epoch 31/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0
200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9398 - loss: 0.1833
# Epoch 161/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9424 - loss: 0.1733
# Epoch 162/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.9425 - loss: 0.1673
# Epoch 163/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9423 - loss: 0.1733
# Epoch 164/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.9405 - loss: 0.1783
# Epoch 165/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.9419 - loss: 0.1755
# Epoch 166/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.9388 - loss: 0.1856
# Epoch 167/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.9418 - loss: 0.1888
# Epoch 168/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9404 - loss: 0.1771
# Epoch 169/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9438 - loss: 0.1702
# Epoch 170/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9457 - loss: 0.1660
# Epoch 171/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9463 - loss: 0.1624
# Epoch 172/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9409 - loss: 0.1798
# Epoch 173/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9418 - loss: 0.1772
# Epoch 174/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9395 - loss: 0.1812
# Epoch 175/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9439 - loss: 0.1701
# Epoch 176/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9417 - loss: 0.1722
# Epoch 177/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9420 - loss: 0.1793
# Epoch 178/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9416 - loss: 0.1825
# Epoch 179/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9409 - loss: 0.1778
# Epoch 180/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9385 - loss: 0.1792
# Epoch 181/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.9421 - loss: 0.1719
# Epoch 182/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9442 - loss: 0.1635
# Epoch 183/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9415 - loss: 0.1754
# Epoch 184/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9407 - loss: 0.1770
# Epoch 185/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9412 - loss: 0.1719
# Epoch 186/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9424 - loss: 0.1750
# Epoch 187/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.9411 - loss: 0.1770
# Epoch 188/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.9437 - loss: 0.1760
# Epoch 189/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9402 - loss: 0.1833
# Epoch 190/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.9406 - loss: 0.1736
# Epoch 191/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9428 - loss: 0.1708
# Epoch 192/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.9436 - loss: 0.1726
# Epoch 193/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.9449 - loss: 0.1677
# Epoch 194/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.9430 - loss: 0.1695
# Epoch 195/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9460 - loss: 0.1627
# Epoch 196/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9423 - loss: 0.1679
# Epoch 197/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9436 - loss: 0.1688
# Epoch 198/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9406 - loss: 0.1766
# Epoch 199/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.9418 - loss: 0.1714
# Epoch 200/200
# 504/504 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9423 - loss: 0.1682

# %%
# 🔮 Step 7: Prediction Function
def predict_next_word(seed_text):
    token_list = tokenizer.texts_to_sequences([seed_text])[0]
    token_list = pad_sequences([token_list], maxlen=max_sequence_len - 1, padding='pre')
    predicted = model.predict(token_list, verbose=0)
    predicted_word_index = np.argmax(predicted)
    for word, index in tokenizer.word_index.items():
        if index == predicted_word_index:
            return word
    return ""

# %%
# # 🎯 Step 8: Try it!
# seed_text = "I am going"
# next_word = predict_next_word(seed_text, max_sequence_len)
# print(f"{seed_text} → {next_word}")

# %%
# Streamlit UI
st.title("Ramayan AI")
user_input = st.text_input("Enter your phrase:", "What is The Ramayana about?") 

if st.button("Predict"):
    next_word = predict_next_word(user_input)
    st.success(f"Next word prediction: **{next_word}**")
# Out:
# 2025-05-11 14:45:49.830 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 14:45:49.833 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 14:45:49.834 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 14:45:49.834 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 14:45:49.835 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 14:45:49.836 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 14:45:49.836 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 14:45:49.837 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 14:45:49.837 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 14:45:49.838 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 14:45:49.840 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 14:45:49.840 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-11 14:45:49.841 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
